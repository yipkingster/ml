# %%
from jax import numpy as jnp
from jax import random
import jax

# double precision isn't available by default.
# x = random.normal(random.key(0), (10,), dtype=jnp.float64)
jax.config.update("jax_enable_x64", True)
x = random.normal(random.key(0), (10,), dtype=jnp.float64)
print(x)
x.dtype
# Out:
# [-0.20584214 -0.78476578  1.81608667  0.18784401  0.08086788 -0.37211079
#   1.19016372  0.33864229  0.08482584 -0.87181784]
# dtype('float64')
